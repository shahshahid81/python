# %%
print("Demo 2")
# Out:
# Demo 2

# %%
for i in range(2,10,2):
    print(i)
# Out:
# 2
# 4
# 6
# 8

# %%
print("Done!")
# Out:
# Done!

# %%
from datetime import datetime
current = datetime.utcnow()
current
# Out:
# datetime.datetime(2026, 6, 8, 18, 28, 23, 320373)
